# %%
from dotenv import load_dotenv
from sys import argv
from pathlib import Path
from langchain_google_community import GmailToolkit
import os
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent


load_dotenv()

# it uses openrouter api key but it should be named openau_api_key
llm = ChatOpenAI(model="openai/gpt-4o-mini-2024-07-18", temperature=0.6, openai_api_key=os.environ["OPENAI_API_KEY"], openai_api_base="https://openrouter.ai/api/v1")

toolkit = GmailToolkit()
tools = toolkit.get_tools()
agent_executor = create_react_agent(llm, tools)

# %%
tools
# Out:
# [GmailCreateDraft(api_resource=<googleapiclient.discovery.Resource object at 0x741c804ae0c0>),
#  GmailSendMessage(api_resource=<googleapiclient.discovery.Resource object at 0x741c804ae0c0>),
#  GmailSearch(api_resource=<googleapiclient.discovery.Resource object at 0x741c804ae0c0>),
#  GmailGetMessage(api_resource=<googleapiclient.discovery.Resource object at 0x741c804ae0c0>),
#  GmailGetThread(api_resource=<googleapiclient.discovery.Resource object at 0x741c804ae0c0>)]

# %%
while True:
    question = input("\033[92mPosez votre question ou tapez 'q' pour quitter: \033[0m")
    if question == 'q':
        break
    events = agent_executor.stream(
        {"messages": [("user", question)]},
        stream_mode="values",
    )
    for event in events:
        event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# what events i have in google calendar this week
# ================================== Ai Message ==================================
# Tool Calls:
#   search_gmail (call_E2tXMX5SdQ31asGpyI80WCgy)
#  Call ID: call_E2tXMX5SdQ31asGpyI80WCgy
#   Args:
#     query: calendar events
#     resource: threads
# ================================= Tool Message =================================
# Name: search_gmail
#
# [{"id": "192586335d0ca3a6", "snippet": "was a <b>calendar</b> app that fully integrated with your Notion workspace? Meet Notion <b>Calendar</b>. It&#39;s a better way to manage", "historyId": "71927", "messages": [{"snippet": "Meet Notion Calendar. ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌", "id": "192586335d0ca3a6"}]}, {"id": "18f44557c5f5c80e", "snippet": "toscheduling Google <b>Calendar</b> <b>events</b> , learn all the ways Automations can give you control of your workflow. Get started", "historyId": "28489", "messages": [{"snippet": "Learn how automations can save you time Airtable logo Let automations help you focus Connected circles Automations help you cut down on time spent repeating tasks, keeping your team updated on changes,", "id": "18f44557c5f5c80e"}]}]
# ================================== Ai Message ==================================
#
# I couldn't find specific calendar events in your Gmail. To check your Google Calendar events for this week, you may need to access your Google Calendar directly. Would you like assistance with anything else?
